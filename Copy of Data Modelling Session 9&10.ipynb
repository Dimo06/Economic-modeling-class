# %% [markdown]
# # <center>Data Modeling - Session 9&10 </center>
# <img src="https://datasemantics.co/wp-content/uploads/2021/01/it-heads-guide-to-data-modelling.jpg">
#
#
#
#
# Here are the things we will do in these sessions:
#
# 1.   Pandas
# 2.   More Data Visualization
#
# <br><br>

# %% [markdown]
# #<center>PANDAS
#
# <img src=https://www.adictosaltrabajo.com/wp-content/uploads/2020/12/1200px-Pandas_logo.svg_-1068x432.png width=400>
#
# <img src="https://images.seattletimes.com/wp-content/uploads/2018/03/03292018_Pandas_150403_tzr.jpg?d=780x501">

# %% [markdown]
# ## What is Pandas?
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.<br>
#
# ##Library Highlights
# - A fast and efficient DataFrame object for data manipulation with integrated indexing;
#
# - Tools for reading and writing data between in-memory data structures and different formats: CSV and text files, Microsoft Excel, SQL databases, and the fast HDF5 format;
#
# - Intelligent data alignment and integrated handling of missing data: gain automatic label-based alignment in computations and easily manipulate messy data into an orderly form;
#
# - Flexible reshaping and pivoting of data sets;
#
# - Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
#
# - Columns can be inserted and deleted from data structures for size mutability;
#
# - Aggregating or transforming data with a powerful group by engine allowing split-apply-combine operations on data sets;
#
# - High performance merging and joining of data sets;
#
# - Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
#
# - Time series-functionality: date range generation and frequency conversion, moving window statistics, date shifting and lagging. Even create domain-specific time offsets and join time series without losing data;
#
# - Highly optimized for performance, with critical code paths written in Cython or C.
#
# - Python with pandas is in use in a wide variety of academic and commercial domains, including Finance, Neuroscience, Economics, Statistics, Advertising, Web Analytics, and more.
#
# ##Mission
# Pandas aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language.
#
# ##Vision
# A world where data analytics and manipulation software is:
#
# - Accessible to everyone
# - Free for users to use and modify
# - Flexible
# - Powerful
# - Easy to use
# - Fast

# %% [markdown]
# ## Where to learn about Pandas?
#
# <img src=https://assets.entrepreneur.com/content/3x2/2000/20181119204233-GettyImages-140892148-edit.jpeg width=400>
#
#
# [Pandas Website](https://pandas.pydata.org/)
#
# Let's go over an introduction to Pandas from the official website:<br>
# [10 Minutes to Pandas*](https://pandas.pydata.org/docs/user_guide/10min.html) <br>
# <sub> \*more like 30+ minutes </sub>

# %% [markdown]
# ## IE Students when they need to learn by themselves

# %%
from IPython.display import HTML

# Use the direct URL to the GIF
HTML('<img src="https://media1.tenor.com/m/xrUe4KFY0dsAAAAC/brother-ew-ew.gif" width="800">')
# Out:
# <img src="https://media1.tenor.com/m/xrUe4KFY0dsAAAAC/brother-ew-ew.gif" width="800">

# %%
from IPython.display import HTML

# Use the direct URL to the GIF
HTML('<img src="https://i.imgflip.com/7dsbg9.jpg" width="800">')
# Out:
# <img src="https://i.imgflip.com/7dsbg9.jpg" width="800">

# %%
# these are the imports
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=[1,2,4,5,6,9])
print(s)
print(s[4])
print(s[9])
print(s.index)
print(s.values)
print(s.values[4], s[6])
# Out:
# 1    1.0
# 2    3.0
# 4    5.0
# 5    NaN
# 6    6.0
# 9    8.0
# dtype: float64
# 5.0
# 8.0
# Index([1, 2, 4, 5, 6, 9], dtype='int64')
# [ 1.  3.  5. nan  6.  8.]
# 6.0 6.0

# %%
dates = pd.date_range("20240329", periods=60000, freq="B")

df = pd.DataFrame(np.random.randn(60000, 4), index=dates, columns=list("ABCD"))
# df = pd.DataFrame(np.random.randint(1, 100, (60000, 4)), index=dates, columns=list("ABCD"))

df

# df.index
# Out:
#                    A         B         C         D
# 2024-03-29  0.995033 -0.585336  1.166999 -1.543140
# 2024-04-01 -1.104101 -0.117632  0.652979  0.127411
# 2024-04-02  1.443761 -0.512242  0.007429 -2.046814
# 2024-04-03 -0.701935  0.954483 -0.519776  0.744133
# 2024-04-04 -0.523553  0.432931 -1.874940 -1.198707
# ...              ...       ...       ...       ...
# 2254-03-17 -1.743531 -0.364649 -2.228480  0.251964
# 2254-03-20  0.377331 -0.357224  0.558239 -0.071939
# 2254-03-21 -1.587260  0.037051  1.888872  0.666080
# 2254-03-22  0.956076 -1.153231  0.200070  0.294610
# 2254-03-23  1.072279  0.756363  0.719530  0.402735
#
# [60000 rows x 4 columns]

# %%
# @title A

from matplotlib import pyplot as plt
df['A'].plot(kind='hist', bins=99, title='A')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo"
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
print(df.index)
print("-----")
df.describe()
# Out:
# DatetimeIndex(['2024-03-29', '2024-04-01', '2024-04-02', '2024-04-03',
#                '2024-04-04', '2024-04-05', '2024-04-08', '2024-04-09',
#                '2024-04-10', '2024-04-11',
#                ...
#                '2254-03-10', '2254-03-13', '2254-03-14', '2254-03-15',
#                '2254-03-16', '2254-03-17', '2254-03-20', '2254-03-21',
#                '2254-03-22', '2254-03-23'],
#               dtype='datetime64[ns]', length=60000, freq='B')
# -----
#                   A             B             C             D
# count  60000.000000  60000.000000  60000.000000  60000.000000
# mean      -0.002735      0.000169      0.000957     -0.001546
# std        1.004230      1.003091      0.999867      0.998538
# min       -3.920849     -3.980264     -4.491071     -4.347970
# 25%       -0.685079     -0.674538     -0.668503     -0.674732
# 50%       -0.002664      0.002711      0.000376      0.002339
# 75%        0.676186      0.674105      0.672818      0.671529
# max        3.889141      4.107450      4.268228      4.249597

# %%
print(df.T)

print(df.sort_values(by="B", ascending=False))
print(df)
# Out:
#    2024-03-29  2024-04-01  2024-04-02  2024-04-03  2024-04-04  2024-04-05  \
# A    0.995033   -1.104101    1.443761   -0.701935   -0.523553   -1.183223
# B   -0.585336   -0.117632   -0.512242    0.954483    0.432931    1.182441
# C    1.166999    0.652979    0.007429   -0.519776   -1.874940   -1.400945
# D   -1.543140    0.127411   -2.046814    0.744133   -1.198707    2.592450
#
#    2024-04-08  2024-04-09  2024-04-10  2024-04-11  ...  2254-03-10  \
# A   -1.234387   -0.698154   -0.047426    0.624509  ...   -0.306708
# B   -0.337760   -0.361058   -0.841745    1.656482  ...   -0.789038
# C   -0.040062    0.887727    0.405724   -1.228282  ...    0.621486
# D    1.139683   -1.126500    0.910505   -1.007747  ...   -0.619400
#
#    2254-03-13  2254-03-14  2254-03-15  2254-03-16  2254-03-17  2254-03-20  \
# A   -0.523568    1.173276   -0.307286   -0.832974   -1.743531    0.377331
# B   -2.791639   -0.038983   -0.496429    1.035541   -0.364649   -0.357224
# C   -0.416659   -0.730404    0.241800    0.495581   -2.228480    0.558239
# D   -1.144944   -1.836303   -0.642447    0.822174    0.251964   -0.071939
#
#    2254-03-21  2254-03-22  2254-03-23
# A   -1.587260    0.956076    1.072279
# B    0.037051   -1.153231    0.756363
# C    1.888872    0.200070    0.719530
# D    0.666080    0.294610    0.402735
#
# [4 rows x 60000 columns]
#                    A         B         C         D
# 2250-12-24  0.094764  4.107450  0.031063 -1.014565
# 2154-02-28  0.906288  3.787965 -0.101497 -1.345166
# 2182-11-07  0.568325  3.725631  0.697896 -0.754619
# 2208-11-21 -0.911623  3.713675 -0.363839  1.550129
# 2227-09-25 -1.436780  3.592774 -0.925524  1.762281
# ...              ...       ...       ...       ...
# 2156-07-06  0.339556 -3.854098 -0.929432 -1.619919
# 2177-04-15 -0.505447 -3.916418  2.115062  0.516660
# 2042-04-09 -1.339388 -3.919551 -0.110947 -0.227691
# 2251-06-10  0.715345 -3.922895 -1.177243 -0.135542
# 2117-11-24  1.342064 -3.980264 -1.009023 -0.328172
#
# [60000 rows x 4 columns]
#                    A         B         C         D
# 2024-03-29  0.995033 -0.585336  1.166999 -1.543140
# 2024-04-01 -1.104101 -0.117632  0.652979  0.127411
# 2024-04-02  1.443761 -0.512242  0.007429 -2.046814
# 2024-04-03 -0.701935  0.954483 -0.519776  0.744133
# 2024-04-04 -0.523553  0.432931 -1.874940 -1.198707
# ...              ...       ...       ...       ...
# 2254-03-17 -1.743531 -0.364649 -2.228480  0.251964
# 2254-03-20  0.377331 -0.357224  0.558239 -0.071939
# 2254-03-21 -1.587260  0.037051  1.888872  0.666080
# 2254-03-22  0.956076 -1.153231  0.200070  0.294610
# 2254-03-23  1.072279  0.756363  0.719530  0.402735
#
# [60000 rows x 4 columns]

# %% [markdown]
# ## Selection

# %%
print(df)
print(df["A"]) # df.A dot notation
print(df.B)
print("----")
print(type(df.A))
print(df.A.values)

print(type(df.A.values))
# Out:
#                    A         B         C         D
# 2024-03-29  0.995033 -0.585336  1.166999 -1.543140
# 2024-04-01 -1.104101 -0.117632  0.652979  0.127411
# 2024-04-02  1.443761 -0.512242  0.007429 -2.046814
# 2024-04-03 -0.701935  0.954483 -0.519776  0.744133
# 2024-04-04 -0.523553  0.432931 -1.874940 -1.198707
# ...              ...       ...       ...       ...
# 2254-03-17 -1.743531 -0.364649 -2.228480  0.251964
# 2254-03-20  0.377331 -0.357224  0.558239 -0.071939
# 2254-03-21 -1.587260  0.037051  1.888872  0.666080
# 2254-03-22  0.956076 -1.153231  0.200070  0.294610
# 2254-03-23  1.072279  0.756363  0.719530  0.402735
#
# [60000 rows x 4 columns]
# 2024-03-29    0.995033
# 2024-04-01   -1.104101
# 2024-04-02    1.443761
# 2024-04-03   -0.701935
# 2024-04-04   -0.523553
#                 ...
# 2254-03-17   -1.743531
# 2254-03-20    0.377331
# 2254-03-21   -1.587260
# 2254-03-22    0.956076
# 2254-03-23    1.072279
# Freq: B, Name: A, Length: 60000, dtype: float64
# 2024-03-29   -0.585336
# 2024-04-01   -0.117632
# 2024-04-02   -0.512242
# 2024-04-03    0.954483
# 2024-04-04    0.432931
#                 ...
# 2254-03-17   -0.364649
# 2254-03-20   -0.357224
# 2254-03-21    0.037051
# 2254-03-22   -1.153231
# 2254-03-23    0.756363
# Freq: B, Name: B, Length: 60000, dtype: float64
# ----
# <class 'pandas.core.series.Series'>
# [ 0.99503253 -1.10410149  1.44376103 ... -1.58725954  0.9560765
#   1.07227903]
# <class 'numpy.ndarray'>

# %%
# slice
print(df[1:3]["A"])
print(df[20:33]["B"])
# Out:
# 2024-04-01   -1.104101
# 2024-04-02    1.443761
# Freq: B, Name: A, dtype: float64
# 2024-04-26   -1.282289
# 2024-04-29    0.666431
# 2024-04-30    0.429997
# 2024-05-01   -0.574109
# 2024-05-02   -0.424026
# 2024-05-03   -1.939639
# 2024-05-06   -1.625030
# 2024-05-07   -0.390702
# 2024-05-08    0.240814
# 2024-05-09    0.291616
# 2024-05-10    1.075926
# 2024-05-13    1.638016
# 2024-05-14   -0.224181
# Freq: B, Name: B, dtype: float64

# %%
# selection withb loc (by value)

dates[1] # this is the index for the second row
print(df)
print("-----")
print(dates[1])
print(df.loc[dates[1]])
# Out:
#                    A         B         C         D
# 2024-03-29  0.995033 -0.585336  1.166999 -1.543140
# 2024-04-01 -1.104101 -0.117632  0.652979  0.127411
# 2024-04-02  1.443761 -0.512242  0.007429 -2.046814
# 2024-04-03 -0.701935  0.954483 -0.519776  0.744133
# 2024-04-04 -0.523553  0.432931 -1.874940 -1.198707
# ...              ...       ...       ...       ...
# 2254-03-17 -1.743531 -0.364649 -2.228480  0.251964
# 2254-03-20  0.377331 -0.357224  0.558239 -0.071939
# 2254-03-21 -1.587260  0.037051  1.888872  0.666080
# 2254-03-22  0.956076 -1.153231  0.200070  0.294610
# 2254-03-23  1.072279  0.756363  0.719530  0.402735
#
# [60000 rows x 4 columns]
# -----
# 2024-04-01 00:00:00
# A   -1.104101
# B   -0.117632
# C    0.652979
# D    0.127411
# Name: 2024-04-01 00:00:00, dtype: float64

# %%
# multiple selection with loc
print(df)
print("------")
print(df.loc[[df.index[1],dates[4], dates[200]], ["A", "C"]])
# Out:
#                    A         B         C         D
# 2024-03-29  0.995033 -0.585336  1.166999 -1.543140
# 2024-04-01 -1.104101 -0.117632  0.652979  0.127411
# 2024-04-02  1.443761 -0.512242  0.007429 -2.046814
# 2024-04-03 -0.701935  0.954483 -0.519776  0.744133
# 2024-04-04 -0.523553  0.432931 -1.874940 -1.198707
# ...              ...       ...       ...       ...
# 2254-03-17 -1.743531 -0.364649 -2.228480  0.251964
# 2254-03-20  0.377331 -0.357224  0.558239 -0.071939
# 2254-03-21 -1.587260  0.037051  1.888872  0.666080
# 2254-03-22  0.956076 -1.153231  0.200070  0.294610
# 2254-03-23  1.072279  0.756363  0.719530  0.402735
#
# [60000 rows x 4 columns]
# ------
#                    A         C
# 2024-04-01 -1.104101  0.652979
# 2024-04-04 -0.523553 -1.874940
# 2025-01-03  0.943866 -0.597358

# %%
df = pd.DataFrame(np.random.randn(5, 5), index=[1, 2, 3, 4, 5], columns=list("ABCDE"))
df
# Out:
#           A         B         C         D         E
# 1  0.593139 -0.235638  1.191249  0.621136 -0.303671
# 2  1.682531  0.919027  0.262774  0.317766 -0.385528
# 3  1.856382  1.249553  1.590655  0.369099  0.117111
# 4 -0.909288 -0.514325  0.694982 -0.481143 -1.670404
# 5 -0.749031  1.158951 -0.837133  1.128951 -0.344983

# %%
df.loc[[3,1], ["C", "D"]]
# Out:
#           C         D
# 3  1.590655  0.369099
# 1  1.191249  0.621136

# %% [markdown]
# ## Selection by position (iloc)

# %%
print(df)
print("----")
print(df.iloc[1])
print("----")
print(df.iloc[3, 3])
print(df.iloc[1:3, 1:2])
print("----")
print(df.iloc[[0,2,4], [1,3]])
# Out:
#           A         B         C         D         E
# 1  0.593139 -0.235638  1.191249  0.621136 -0.303671
# 2  1.682531  0.919027  0.262774  0.317766 -0.385528
# 3  1.856382  1.249553  1.590655  0.369099  0.117111
# 4 -0.909288 -0.514325  0.694982 -0.481143 -1.670404
# 5 -0.749031  1.158951 -0.837133  1.128951 -0.344983
# ----
# A    1.682531
# B    0.919027
# C    0.262774
# D    0.317766
# E   -0.385528
# Name: 2, dtype: float64
# ----
# -0.4811430192812695
#           B
# 2  0.919027
# 3  1.249553
# ----
#           B         D
# 1 -0.235638  0.621136
# 3  1.249553  0.369099
# 5  1.158951  1.128951

# %%
# boolean idexing
print(df)
print("---")
print(df[df["A"] > 0])
# Out:
#           A         B         C         D         E
# 1  0.593139 -0.235638  1.191249  0.621136 -0.303671
# 2  1.682531  0.919027  0.262774  0.317766 -0.385528
# 3  1.856382  1.249553  1.590655  0.369099  0.117111
# 4 -0.909288 -0.514325  0.694982 -0.481143 -1.670404
# 5 -0.749031  1.158951 -0.837133  1.128951 -0.344983
# ---
#           A         B         C         D         E
# 1  0.593139 -0.235638  1.191249  0.621136 -0.303671
# 2  1.682531  0.919027  0.262774  0.317766 -0.385528
# 3  1.856382  1.249553  1.590655  0.369099  0.117111

# %% [markdown]
# Adding data

# %%
df["E"] = ["car", "toy"] * 2 + ["ship"]
df["James"] = [7] * 5
df["James"] = 11
print(df)
# Out:
#           A         B         C         D     E  James
# 1  0.593139 -0.235638  1.191249  0.621136   car     11
# 2  1.682531  0.919027  0.262774  0.317766   toy     11
# 3  1.856382  1.249553  1.590655  0.369099   car     11
# 4 -0.909288 -0.514325  0.694982 -0.481143   toy     11
# 5 -0.749031  1.158951 -0.837133  1.128951  ship     11

# %%
import matplotlib.pylab as plt
print(df)

#

plt.plot(df.index, df.A)

df[['A', 'B']].plot()
# Out:
#           A         B         C         D     E  James
# 1  0.593139 -0.235638  1.191249  0.621136   car     11
# 2  1.682531  0.919027  0.262774  0.317766   toy     11
# 3  1.856382  1.249553  1.590655  0.369099   car     11
# 4 -0.909288 -0.514325  0.694982 -0.481143   toy     11
# 5 -0.749031  1.158951 -0.837133  1.128951  ship     11
# <Axes: >

# %% [markdown]
# #<center> Practical Example
# Apple stock over the years and the launch of Iphones
#
# ![](https://drive.google.com/uc?id=1RGgV6RcSuNFNZ11RCRxs3ms0K9oXwJrH)

# %%
# !pip install --upgrade pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pandas-datareader) (4.9.4)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.10/dist-packages (from pandas-datareader) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-datareader) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-datareader) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.38)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.25.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.2.2)

# %%
import requests

r = requests.get("https://github.com/itb-ie/pandas-apple-stock/raw/master/iphone-dates-2019.xlsx")
with open("sample_data/launch.xlsx", "wb") as f:
  f.write(r.content)

# %%
# !wget https://github.com/itb-ie/pandas-apple-stock/raw/master/iphone-dates-2019.xlsx -O sample_data/launch2.xlsx
# Out:
# --2024-05-17 14:11:10--  https://github.com/itb-ie/pandas-apple-stock/raw/master/iphone-dates-2019.xlsx
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/itb-ie/pandas-apple-stock/master/iphone-dates-2019.xlsx [following]
# --2024-05-17 14:11:10--  https://raw.githubusercontent.com/itb-ie/pandas-apple-stock/master/iphone-dates-2019.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10992 (11K) [application/octet-stream]
# Saving to: ‘sample_data/launch2.xlsx’
#
# sample_data/launch2 100%[===================>]  10.73K  --.-KB/s    in 0s
#
# 2024-05-17 14:11:10 (65.8 MB/s) - ‘sample_data/launch2.xlsx’ saved [10992/10992]

# %%
from matplotlib import pylab as plt
import pandas as pd
import pandas_datareader.data as web
import yfinance as yfin

yfin.pdr_override()

df1 = web.DataReader('AAPL', start='2007-01-01', end='2024-04-21')

# df1.Close.plot()
df2 = pd.read_excel("sample_data/launch.xlsx")

df2['Date'] = pd.to_datetime(df2.date)
df1['Date'] = pd.to_datetime(df1.index)
df1.insert(0, 'ID', range(0, len(df1)))
# print(df1)
# print(df2)

index2 = []
for date2 in df2.Date:
    if df1.ID[df1.Date == date2].values.size:
        index2.append(int(df1.ID[df1.Date == date2].values[0]))
    elif df1.ID[df1.Date == date2 + pd.DateOffset(1)].values.size:
        index2.append(int(df1.ID[df1.Date == date2 + pd.DateOffset(1)].values[0]))
    elif df1.ID[df1.Date == date2 + pd.DateOffset(2)].values.size:
        index2.append(int(df1.ID[df1.Date == date2 + pd.DateOffset(2)].values[0]))

    else:
        print(f"Did not find {date2}")

print(index2)

plt.figure("Apple Stock")
plt.figure(figsize = (20, 10))
plt.plot(df1["Date"], df1["Close"], '-^', ms=11, mfc="red", linewidth=0.6,
         markevery=index2, label="Iphone launch date")
plt.xlabel("Dates")
plt.legend(loc="upper left")
plt.show()
df1.to_csv("sample_data/result.csv")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [2951, 2976, 2730, 2326, 2700, 2444, 2194, 1943, 1683, 1442, 1206, 872, 620, 375, 3201, 174, 3477, 3708, 3954, 4209]

# %%
# Plotting using pandas' built-in functionality
ax = df1['Close'].plot(
    figsize=(20, 10),
    style='-ob',
    linewidth=0.3,
    markevery=index2,  # Highlight the launch dates
    markerfacecolor='green',
    markersize=11,
    label='Close Price'
)

# Highlight iPhone launch dates with vertical lines
for launch_date in df1.iloc[index2].index:
    ax.axvline(x=launch_date, color='gray', linestyle='--', linewidth=0.5)

# Labeling and legend
ax.set_xlabel("Date")
ax.set_ylabel("Close Price")
ax.set_title("Apple Stock Prices with iPhone Launch Dates Highlighted")
ax.legend(loc="upper left")

# Show the plot
plt.show()

# %%
from matplotlib import pylab as plt
import pandas as pd
import pandas_datareader.data as web

company = "NVDA"
df = web.DataReader(company, start='2024-01-01', end='2024-04-18')
# print(df)

plt.style.use("default")

plt.figure(f"{company} CandleStick", figsize=(20,10))
plt.title(f"{company} CandleStick")
# plt.plot(df.index, df.Close)
plt.vlines(x=df.index, ymin=df.Low, ymax=df.High, color="gray")

green = df[df.Open <= df.Close].copy()
green['Height'] = green.Close - green.Open

red = df[df.Open > df.Close].copy()
red['Height'] = red.Open - red.Close

plt.bar(x=green.index, height=green.Height, bottom=green.Open, color="green")
plt.bar(x=red.index, height=red.Height, bottom=red.Close, color="red")


plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# Here are the things we will do in this session:
#
# More pandas!
#
# ![](https://i.natgeofe.com/n/1e38ab75-6d81-45e9-817c-3181a146165e/01pandainsemination_3x2.jpg?w=718&h=479)

# %%
from IPython.display import HTML

# Use the direct URL to the GIF
HTML('<img src="https://media.tenor.com/9icIB76KxhgAAAAC/captain-america-i-can-do-this-all-day.gif" width="800">')
# Out:
# <img src="https://media.tenor.com/9icIB76KxhgAAAAC/captain-america-i-can-do-this-all-day.gif" width="800">

# %%
import pandas as pd

# Load the data
df = pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")

# Filter data according to specific criteria
df_filtered = df[(df.year >= 2005) & (df.sex == "boy") & (df.percent > 0.005)]

# Group by 'name' and calculate the mean of the 'percent' column only
grouped = df_filtered.groupby('name')['percent'].mean()
print(grouped)

# Convert the Series back to DataFrame for further manipulation if necessary
mean_df = grouped.reset_index()

# Sort the data by 'percent' in descending order
sorted_mean_df = mean_df.sort_values(by="percent", ascending=False)

# Display the results
print(sorted_mean_df.values)
# Out:
# name
# Aiden          0.006125
# Alexander      0.008402
# Andrew         0.008692
# Angel          0.005203
# Anthony        0.008815
# Benjamin       0.006146
# Brandon        0.005658
# Caleb          0.005068
# Christian      0.006402
# Christopher    0.008855
# Daniel         0.009120
# David          0.007975
# Dylan          0.005917
# Elijah         0.005641
# Ethan          0.009553
# Gabriel        0.005879
# Gavin          0.005391
# Jack           0.005135
# Jackson        0.005308
# Jacob          0.011196
# James          0.007283
# Jayden         0.007380
# John           0.006738
# Jonathan       0.006366
# Jose           0.005355
# Joseph         0.008203
# Joshua         0.009802
# Kevin          0.005135
# Logan          0.006639
# Matthew        0.008970
# Michael        0.010212
# Nathan         0.006374
# Nicholas       0.006854
# Noah           0.007186
# Ryan           0.007456
# Samuel         0.006192
# Tyler          0.006822
# William        0.008642
# Zachary        0.005401
# Name: percent, dtype: float64
# [['Jacob' 0.0111955]
#  ['Michael' 0.0102125]
#  ['Joshua' 0.00980175]
#  ['Ethan' 0.00955325]
#  ['Daniel' 0.00911975]
#  ['Matthew' 0.00896975]
#  ['Christopher' 0.00885475]
#  ['Anthony' 0.00881525]
#  ['Andrew' 0.008692]
#  ['William' 0.008642]
#  ['Alexander' 0.008402]
#  ['Joseph' 0.00820275]
#  ['David' 0.007975]
#  ['Ryan' 0.00745575]
#  ['Jayden' 0.00738]
#  ['James' 0.0072829999999999995]
#  ['Noah' 0.007185749999999999]
#  ['Nicholas' 0.006854]
#  ['Tyler' 0.0068215]
#  ['John' 0.0067382499999999994]
#  ['Logan' 0.0066385]
#  ['Christian' 0.0064017499999999995]
#  ['Nathan' 0.0063745]
#  ['Jonathan' 0.006366]
#  ['Samuel' 0.00619175]
#  ['Benjamin' 0.00614625]
#  ['Aiden' 0.006124666666666667]
#  ['Dylan' 0.00591675]
#  ['Gabriel' 0.00587875]
#  ['Brandon' 0.00565775]
#  ['Elijah' 0.005641]
#  ['Zachary' 0.005400500000000001]
#  ['Gavin' 0.0053905]
#  ['Jose' 0.005354666666666667]
#  ['Jackson' 0.005308]
#  ['Angel' 0.005203333333333333]
#  ['Kevin' 0.005135]
#  ['Jack' 0.005135]
#  ['Caleb' 0.005068]]

# %%
import pandas as pd

# Load the data
df = pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")

# Filter data according to specific criteria
df_filtered = df[(df.year <= 1900) & (df.sex == "boy") & (df.percent > 0.005)]

# Group by 'name' and calculate the mean of the 'percent' column only
grouped = df_filtered.groupby('name')['percent'].mean()

# Convert the Series back to DataFrame for further manipulation if necessary
mean_df = grouped.reset_index()

# Sort the data by 'percent' in descending order
sorted_mean_df = mean_df.sort_values(by="percent", ascending=False)

# Display the results
print(sorted_mean_df.values)
# Out:
# [['John' 0.0705305238095238]
#  ['William' 0.06483895238095239]
#  ['James' 0.04363485714285714]
#  ['George' 0.03765185714285714]
#  ['Charles' 0.03437814285714286]
#  ['Frank' 0.024661000000000002]
#  ['Joseph' 0.022936809523809526]
#  ['Robert' 0.020966761904761905]
#  ['Henry' 0.018921190476190477]
#  ['Edward' 0.018680047619047617]
#  ['Thomas' 0.018533761904761907]
#  ['Harry' 0.018074238095238095]
#  ['Walter' 0.015563142857142857]
#  ['Arthur' 0.013416666666666667]
#  ['Fred' 0.012317904761904763]
#  ['Albert' 0.011646809523809523]
#  ['Clarence' 0.00857204761904762]
#  ['Dewey' 0.008439]
#  ['Willie' 0.007560625]
#  ['Roy' 0.0073818235294117645]
#  ['Samuel' 0.006999047619047619]
#  ['Louis' 0.006940571428571428]
#  ['Harold' 0.006872285714285714]
#  ['Paul' 0.006744]
#  ['Grover' 0.006579]
#  ['Earl' 0.006514769230769231]
#  ['Raymond' 0.0063941]
#  ['Carl' 0.006288500000000001]
#  ['Benjamin' 0.006198]
#  ['David' 0.006164142857142858]
#  ['Joe' 0.006105857142857143]
#  ['Richard' 0.006095666666666668]
#  ['Ernest' 0.006055238095238095]
#  ['Charlie' 0.006011285714285714]
#  ['Jack' 0.0057765]
#  ['Ralph' 0.0057033]
#  ['Jesse' 0.0053428]
#  ['Daniel' 0.005330666666666667]
#  ['Andrew' 0.00528525]
#  ['Will' 0.0052731]
#  ['Herbert' 0.00527]
#  ['Oscar' 0.005232125]
#  ['Howard' 0.0051924]
#  ['Sam' 0.005059]]

# %%
df = pd.read_json("https://covid.cdc.gov/covid-data-tracker/COVIDData/getAjaxData?id=us_trend_by_USA_v2")
df
# Out:
#      runid                           us_trend_by_Geography_v2
# 0     3218  {'Geography': 'USA', 'runid': 3218, 'week_endi...
# 1     3218  {'week_ending_date': '2020-01-11', 'state': 'U...
# 2     3218  {'week_ending_date': '2020-01-18', 'state': 'U...
# 3     3218  {'week_ending_date': '2020-01-25', 'state': 'U...
# 4     3218  {'week_ending_date': '2020-02-01', 'state': 'U...
# ..     ...                                                ...
# 222   3218  {'week_ending_date': '2024-04-06', 'state': 'U...
# 223   3218  {'week_ending_date': '2024-04-13', 'state': 'U...
# 224   3218  {'week_ending_date': '2024-04-20', 'state': 'U...
# 225   3218  {'week_ending_date': '2024-04-27', 'state': 'U...
# 226   3218  {'week_ending_date': '2024-05-04', 'state': 'U...
#
# [227 rows x 2 columns]

# %%
df2 = df['us_trend_by_Geography_v2'].apply(pd.Series)
df2
# Out:
#     Geography   runid week_ending_date state  \
# 0         USA  3218.0       2020-01-04   USA
# 1         NaN     NaN       2020-01-11   USA
# 2         NaN     NaN       2020-01-18   USA
# 3         NaN     NaN       2020-01-25   USA
# 4         NaN     NaN       2020-02-01   USA
# ..        ...     ...              ...   ...
# 222       NaN     NaN       2024-04-06   USA
# 223       NaN     NaN       2024-04-13   USA
# 224       NaN     NaN       2024-04-20   USA
# 225       NaN     NaN       2024-04-27   USA
# 226       NaN     NaN       2024-05-04   USA
#
#      total_adm_all_covid_confirmed_past_7days  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 222                                    7478.0
# 223                                    6584.0
# 224                                    5733.0
# 225                                    5098.0
# 226                                       NaN
#
#      avg_total_patients_hospitalized_covid_confirmed  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 222                                          6717.57
# 223                                          6074.14
# 224                                          5292.57
# 225                                          4603.86
# 226                                              NaN
#
#      sum_adm_all_covid_confirmed  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 222                    6917825.0
# 223                    6924409.0
# 224                    6930142.0
# 225                    6935240.0
# 226                          NaN
#
#      total_adm_all_covid_confirmed_past_7days_per_100k  data_as_of  \
# 0                                                  NaN  2024-05-09
# 1                                                  NaN  2024-05-09
# 2                                                  NaN  2024-05-09
# 3                                                  NaN  2024-05-09
# 4                                                  NaN  2024-05-09
# ..                                                 ...         ...
# 222                                               2.25  2024-05-09
# 223                                               1.98  2024-05-09
# 224                                               1.73  2024-05-09
# 225                                               1.54  2024-05-09
# 226                                                NaN  2024-05-09
#
#      COVID_deaths_weekly  COVID_deaths_total  crude_COVID_rate_weekly  \
# 0                      0                   0                      0.0
# 1                      1                   1                      NaN
# 2                      2                   3                      NaN
# 3                      3                   6                      NaN
# 4                      0                   6                      0.0
# ..                   ...                 ...                      ...
# 222                  583             1189191                      0.2
# 223                  512             1189703                      0.2
# 224                  396             1190099                      0.1
# 225                  294             1190393                      0.1
# 226                  153             1190546                      0.0
#
#      aa_COVID_rate_weekly  crude_COVID_rate_total  aa_COVID_rate_total  \
# 0                     0.0                     0.0                  0.0
# 1                     NaN                     NaN                  NaN
# 2                     NaN                     NaN                  NaN
# 3                     NaN                     NaN                  NaN
# 4                     0.0                     NaN                  NaN
# ..                    ...                     ...                  ...
# 222                   0.1                   358.3                297.8
# 223                   0.1                   358.5                297.9
# 224                   0.1                   358.6                298.0
# 225                   0.1                   358.7                298.1
# 226                   0.0                   358.7                298.1
#
#      COVID_pct_of_total_weekly  number_tested  percent_pos
# 0                          0.0            NaN          NaN
# 1                          0.0            NaN          NaN
# 2                          0.0            NaN          NaN
# 3                          0.0            NaN          NaN
# 4                          0.0            NaN          NaN
# ..                         ...            ...          ...
# 222                        1.1        66874.0          3.5
# 223                        1.0        62170.0          3.4
# 224                        0.9        55651.0          3.1
# 225                        0.7        53084.0          3.0
# 226                        0.7        40997.0          3.1
#
# [227 rows x 18 columns]

# %%
# remove Geography, runid
df2.drop(columns=["Geography", "runid"], inplace=True) # in place means there is no need to assign to another df
df2
# Out:
#     week_ending_date state  total_adm_all_covid_confirmed_past_7days  \
# 0         2020-01-04   USA                                       NaN
# 1         2020-01-11   USA                                       NaN
# 2         2020-01-18   USA                                       NaN
# 3         2020-01-25   USA                                       NaN
# 4         2020-02-01   USA                                       NaN
# ..               ...   ...                                       ...
# 222       2024-04-06   USA                                    7478.0
# 223       2024-04-13   USA                                    6584.0
# 224       2024-04-20   USA                                    5733.0
# 225       2024-04-27   USA                                    5098.0
# 226       2024-05-04   USA                                       NaN
#
#      avg_total_patients_hospitalized_covid_confirmed  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 222                                          6717.57
# 223                                          6074.14
# 224                                          5292.57
# 225                                          4603.86
# 226                                              NaN
#
#      sum_adm_all_covid_confirmed  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 222                    6917825.0
# 223                    6924409.0
# 224                    6930142.0
# 225                    6935240.0
# 226                          NaN
#
#      total_adm_all_covid_confirmed_past_7days_per_100k  data_as_of  \
# 0                                                  NaN  2024-05-09
# 1                                                  NaN  2024-05-09
# 2                                                  NaN  2024-05-09
# 3                                                  NaN  2024-05-09
# 4                                                  NaN  2024-05-09
# ..                                                 ...         ...
# 222                                               2.25  2024-05-09
# 223                                               1.98  2024-05-09
# 224                                               1.73  2024-05-09
# 225                                               1.54  2024-05-09
# 226                                                NaN  2024-05-09
#
#      COVID_deaths_weekly  COVID_deaths_total  crude_COVID_rate_weekly  \
# 0                      0                   0                      0.0
# 1                      1                   1                      NaN
# 2                      2                   3                      NaN
# 3                      3                   6                      NaN
# 4                      0                   6                      0.0
# ..                   ...                 ...                      ...
# 222                  583             1189191                      0.2
# 223                  512             1189703                      0.2
# 224                  396             1190099                      0.1
# 225                  294             1190393                      0.1
# 226                  153             1190546                      0.0
#
#      aa_COVID_rate_weekly  crude_COVID_rate_total  aa_COVID_rate_total  \
# 0                     0.0                     0.0                  0.0
# 1                     NaN                     NaN                  NaN
# 2                     NaN                     NaN                  NaN
# 3                     NaN                     NaN                  NaN
# 4                     0.0                     NaN                  NaN
# ..                    ...                     ...                  ...
# 222                   0.1                   358.3                297.8
# 223                   0.1                   358.5                297.9
# 224                   0.1                   358.6                298.0
# 225                   0.1                   358.7                298.1
# 226                   0.0                   358.7                298.1
#
#      COVID_pct_of_total_weekly  number_tested  percent_pos
# 0                          0.0            NaN          NaN
# 1                          0.0            NaN          NaN
# 2                          0.0            NaN          NaN
# 3                          0.0            NaN          NaN
# 4                          0.0            NaN          NaN
# ..                         ...            ...          ...
# 222                        1.1        66874.0          3.5
# 223                        1.0        62170.0          3.4
# 224                        0.9        55651.0          3.1
# 225                        0.7        53084.0          3.0
# 226                        0.7        40997.0          3.1
#
# [227 rows x 16 columns]

# %%
df3 = df2.set_index(keys="week_ending_date")
df3
df3.index

df3.index = pd.to_datetime(df3.index)

# %%
df3.index
# Out:
# DatetimeIndex(['2020-01-04', '2020-01-11', '2020-01-18', '2020-01-25',
#                '2020-02-01', '2020-02-08', '2020-02-15', '2020-02-22',
#                '2020-02-29', '2020-03-07',
#                ...
#                '2024-03-02', '2024-03-09', '2024-03-16', '2024-03-23',
#                '2024-03-30', '2024-04-06', '2024-04-13', '2024-04-20',
#                '2024-04-27', '2024-05-04'],
#               dtype='datetime64[ns]', name='week_ending_date', length=227, freq=None)

# %%
import matplotlib.pyplot as plt
plt.ticklabel_format(style='plain')
df3['COVID_deaths_total'].plot(figsize=(30, 15))
# Out:
# <Axes: xlabel='week_ending_date'>

# %%
import matplotlib.dates as mdates
plt.ticklabel_format(style='plain')


df3['COVID_deaths_weekly'].plot(figsize=(25, 10), kind="bar")
# Out:
# <Axes: xlabel='week_ending_date'>

# %%
new_df = df3.loc[:, ['total_adm_all_covid_confirmed_past_7days', 'COVID_deaths_weekly']]
# new_df['COVID_deaths_weekly'] *= 4
new_df = new_df.iloc[30:100]
# plt.ticklabel_format(style='plain')
new_df.plot(figsize=(20, 10), kind="bar")
# Out:
# <Axes: xlabel='week_ending_date'>

# %%
new_df = df3.loc[:, ['total_adm_all_covid_confirmed_past_7days', 'COVID_deaths_weekly']]
# new_df['COVID_deaths_weekly'] *= 4
new_df = new_df.iloc[-52:]
# plt.ticklabel_format(style='plain')
new_df.plot(figsize=(20, 10), kind="bar")
# Out:
# <Axes: xlabel='week_ending_date'>

# %%
import numpy as np
df1 = pd.DataFrame() # empty data frame
s1 = np.arange(0, 1000)
s2 = np.sin(s1/50)

df1.index = s1
df1['sin'] = s2

df1.plot()
# Out:
# <Axes: >

# %%
df2 = df1.copy()
df2[df2['sin'] > 0.5] = 0.3
df2[df2['sin'] < -0.5] = -0.8

df2.plot()
# Out:
# <Axes: >

# %%
s3 = pd.Series(np.random.randn(1000)/10)
s4 = s3.cumsum()
s4
# Out:
# 0     -0.070364
# 1     -0.071305
# 2     -0.079089
# 3     -0.161342
# 4     -0.211910
#          ...
# 995   -3.177366
# 996   -3.253234
# 997   -3.273802
# 998   -3.328124
# 999   -3.331025
# Length: 1000, dtype: float64

# %%
df2['random'] = s4
df2.plot(figsize=(20, 10))
# Out:
# <Axes: >

# %% [markdown]
# #<Center> Homework
# <img src=http://2.bp.blogspot.com/-KJonHReE80I/VDwLlsZXgEI/AAAAAAAAMcc/_nhlmp4Jk5g/s1600/Do%2Byou%2Bwant%2Bme%2Bto%2Beat%2Bit.jpg >
#
# - Download data for 2-3 companies that are related. For example: Nike and Adidas, Honda and Toyota, etc
# - Plot their stock graph on the same figure over the same period of time
# - Do you observe any correlation?
# - You can use yahoo finance to get the data in .csv format <br>
# https://finance.yahoo.com/quote/NKE/history?p=NKE
# - Or you can use the above example

# %%
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import yfinance as yf

# Override pandas datareader's get_data_yahoo() method to use yfinance
yf.pdr_override()

# Download stock data for Mercedes (symbol: MBG.DE) and Ferrari (symbol: RACE)
start_date = '2021-01-01'
end_date = '2024-05-17'
mercedes_data = web.get_data_yahoo('MBG.DE', start=start_date, end=end_date)
ferrari_data = web.get_data_yahoo('RACE', start=start_date, end=end_date)

# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot Mercedes stock on primary axis
color = 'tab:blue'  # Changed color to blue
ax1.set_xlabel('Date')
ax1.set_ylabel('Mercedes Stock Price (USD)', color=color)
ax1.plot(mercedes_data.index, mercedes_data['Close'], color=color, label='Mercedes')
ax1.tick_params(axis='y', labelcolor=color)

# Create secondary axis for Ferrari
ax2 = ax1.twinx()
color = 'tab:red'  # Changed color to red
ax2.set_ylabel('Ferrari Stock Price (USD)', color=color)
ax2.plot(ferrari_data.index, ferrari_data['Close'], color=color, label='Ferrari')
ax2.tick_params(axis='y', labelcolor=color)

# Title and legend
plt.title('Mercedes vs Ferrari Stock Prices')
fig.tight_layout()
fig.legend(loc='upper left')

plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# The graph above has two sets of axis as i needed to scale up Mercedes stock price visually as there was a great nominal disparity.
#
# From the graph it is clear that both companies experience a lot of similar volatility at the same time periods with many swings up and down correlating.
# with examples like the dip in early 2022 and the beginings of the rebound towards the end of 2022, as well as positive growth throughout most of 2023.
#
# Nevertheless we can see that Ferrari has continued to grow steadily over time whilst mercedes fluctuates up and down and is currently on the downwards trend.
#
# Fun fact the short term slip in Mercedes stock price in February 2024 was caused by Lewis Hamilton leaving to join Ferrari and we can also see a small spike in Ferrari stock at the same time.
